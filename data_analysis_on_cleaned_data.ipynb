# %% [markdown]
# # EDA_project_clean_data_analysis

# %%
cd ~
# Out:
# /home/kenan

# %%
cd Desktop/Metis_DS_BC_2022/MetisBC/Exploratory Data Analysis/Project_Turnstile_data
# Out:
# /home/kenan/Desktop/Metis_DS_BC_2022/MetisBC/Exploratory Data Analysis/Project_Turnstile_data

# %%
# ls -la

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import datetime
from functools import partial, reduce

# %% [markdown]
# ### Load data

# %%
# load 2019 data first
df_19_01 = pd.read_csv('/home/kenan/Desktop/Metis_DS_BC_2022/MetisBC/Exploratory Data Analysis/Project_Turnstile_data/2019_01_clean.csv')
df_19_02 = pd.read_csv('/home/kenan/Desktop/Metis_DS_BC_2022/MetisBC/Exploratory Data Analysis/Project_Turnstile_data/2019_02_clean.csv')
df_19_03 = pd.read_csv('/home/kenan/Desktop/Metis_DS_BC_2022/MetisBC/Exploratory Data Analysis/Project_Turnstile_data/2019_03_clean.csv')
df_19_04 = pd.read_csv('/home/kenan/Desktop/Metis_DS_BC_2022/MetisBC/Exploratory Data Analysis/Project_Turnstile_data/2019_04_clean.csv')
df_19_05 = pd.read_csv('/home/kenan/Desktop/Metis_DS_BC_2022/MetisBC/Exploratory Data Analysis/Project_Turnstile_data/2019_05_clean.csv')
df_19_06 = pd.read_csv('/home/kenan/Desktop/Metis_DS_BC_2022/MetisBC/Exploratory Data Analysis/Project_Turnstile_data/2019_06_clean.csv')
df_19_07 = pd.read_csv('/home/kenan/Desktop/Metis_DS_BC_2022/MetisBC/Exploratory Data Analysis/Project_Turnstile_data/2019_07_clean.csv')
df_19_08 = pd.read_csv('/home/kenan/Desktop/Metis_DS_BC_2022/MetisBC/Exploratory Data Analysis/Project_Turnstile_data/2019_08_clean.csv')
df_19_09 = pd.read_csv('/home/kenan/Desktop/Metis_DS_BC_2022/MetisBC/Exploratory Data Analysis/Project_Turnstile_data/2019_09_clean.csv')
df_19_10 = pd.read_csv('/home/kenan/Desktop/Metis_DS_BC_2022/MetisBC/Exploratory Data Analysis/Project_Turnstile_data/2019_10_clean.csv')
df_19_11 = pd.read_csv('/home/kenan/Desktop/Metis_DS_BC_2022/MetisBC/Exploratory Data Analysis/Project_Turnstile_data/2019_11_clean.csv')
df_19_12 = pd.read_csv('/home/kenan/Desktop/Metis_DS_BC_2022/MetisBC/Exploratory Data Analysis/Project_Turnstile_data/2019_12_clean.csv')

# %%
# # sample month data description
# df_19_07.describe()

# %%
# load 2021 data first
df_21_01 = pd.read_csv('/home/kenan/Desktop/Metis_DS_BC_2022/MetisBC/Exploratory Data Analysis/Project_Turnstile_data/2021_01_clean.csv')
df_21_02 = pd.read_csv('/home/kenan/Desktop/Metis_DS_BC_2022/MetisBC/Exploratory Data Analysis/Project_Turnstile_data/2021_02_clean.csv')
df_21_03 = pd.read_csv('/home/kenan/Desktop/Metis_DS_BC_2022/MetisBC/Exploratory Data Analysis/Project_Turnstile_data/2021_03_clean.csv')
df_21_04 = pd.read_csv('/home/kenan/Desktop/Metis_DS_BC_2022/MetisBC/Exploratory Data Analysis/Project_Turnstile_data/2021_04_clean.csv')
df_21_05 = pd.read_csv('/home/kenan/Desktop/Metis_DS_BC_2022/MetisBC/Exploratory Data Analysis/Project_Turnstile_data/2021_05_clean.csv')
df_21_06 = pd.read_csv('/home/kenan/Desktop/Metis_DS_BC_2022/MetisBC/Exploratory Data Analysis/Project_Turnstile_data/2021_06_clean.csv')
df_21_07 = pd.read_csv('/home/kenan/Desktop/Metis_DS_BC_2022/MetisBC/Exploratory Data Analysis/Project_Turnstile_data/2021_07_clean.csv')
df_21_08 = pd.read_csv('/home/kenan/Desktop/Metis_DS_BC_2022/MetisBC/Exploratory Data Analysis/Project_Turnstile_data/2021_08_clean.csv')
df_21_09 = pd.read_csv('/home/kenan/Desktop/Metis_DS_BC_2022/MetisBC/Exploratory Data Analysis/Project_Turnstile_data/2021_09_clean.csv')
df_21_10 = pd.read_csv('/home/kenan/Desktop/Metis_DS_BC_2022/MetisBC/Exploratory Data Analysis/Project_Turnstile_data/2021_10_clean.csv')
df_21_11 = pd.read_csv('/home/kenan/Desktop/Metis_DS_BC_2022/MetisBC/Exploratory Data Analysis/Project_Turnstile_data/2021_11_clean.csv')
df_21_12 = pd.read_csv('/home/kenan/Desktop/Metis_DS_BC_2022/MetisBC/Exploratory Data Analysis/Project_Turnstile_data/2021_12_clean.csv')

# %%
# # sample month data description
# df_21_01

# %%
### import SQLAlchemy

# from sqlalchemy import create_engine

# engine.execute("SELECT * FROM df_21_07").fetchall()

# # create engine
# engine = create_engine('sqlite://', echo=False)

# # sample:
# df_19_01.to_sql('df_19_01',con=engine)

# from sqlalchemy import inspect
# inspector = inspect(engine)
# inspector.get_table_names()

# q_1 = pd.read_sql('select station,sum(daily_volume) as mv_19_01 from df_19_01 group by station order by station;', engine)
# q_2 = pd.read_sql('select station,sum(daily_volume) as mv_21_01 from df_21_01 group by station order by station;', engine)

# q_1.to_sql('q_1',con=engine) , q_2.to_sql('q_2',con=engine)

# q_3 = pd.read_sql('select q_1.station, q_1.mv_19_01, q_2.mv_21_01 , (q_2.mv_21_01-q_1.mv_19_01) as change, 100 *(q_2.mv_21_01-q_1.mv_19_01)/q_1.mv_19_01 as change_percent  from q_1 left join q_2 on q_1.station = q_2.station where change_percent <100 order by change_percent asc', engine)
# q_3

# sns.barplot(x='STATION',y='change', data=q_3)

# q_4 = pd.read_sql('select q_1.station, q_1.mv_19_01, q_2.mv_21_01 , (q_2.mv_21_01-q_1.mv_19_01) as change, 100 *(q_2.mv_21_01-q_1.mv_19_01)/q_1.mv_19_01 as change_percent  from q_1 left join q_2 on q_1.station = q_2.station where change_percent between -70 and 0 and q_2.mv_21_01 > 300000 order by change_percent asc', engine)
# q_4

# %% [markdown]
# ###  Monthly most crowded stations and plots

# %%
# Jan 2021
df_21_01 = pd.read_csv('/home/kenan/Desktop/Metis_DS_BC_2022/MetisBC/Exploratory Data Analysis/Project_Turnstile_data/2021_01_clean.csv')

# %%
df_21_01_stations_volume = df_21_01.groupby(['STATION'])['DAILY_VOLUME'].sum().sort_values(ascending = False)
df_21_01_stations_volume = pd.DataFrame(df_21_01_stations_volume.reset_index())
df_21_01_stations_volume = df_21_01_stations_volume.rename(columns={"DAILY_VOLUME":"MV_21_01"})
df_21_01_stations_volume
# MV == Monthly Volume
# Out:
#              STATION   MV_21_01
# 0     34 ST-PENN STA  1469903.0
# 1             125 ST  1030262.0
# 2              23 ST   987764.0
# 3              86 ST   975650.0
# 4    34 ST-HERALD SQ   944578.0
# ..               ...        ...
# 373      BEACH 90 ST    14011.0
# 374      BEACH 98 ST     7263.0
# 375    TOMPKINSVILLE     6790.0
# 376     BEACH 105 ST     3952.0
# 377    BROAD CHANNEL     3599.0
#
# [378 rows x 2 columns]

# %%
#Plot graph for TOP 15 STATIONS BASED ON MONTHLY RIDERSHIP 
plt.figure(figsize=(20,8))
plt.title('TOP 15 STATIONS BASED ON MONTHLY VOLUME OF USERS - JAN 2021',family='CALIBRI',fontsize = 20,loc='CENTER',color='black');
sns.barplot(data = df_21_01_stations_volume.head(15), y = df_21_01_stations_volume.head(15).STATION, x = df_21_01_stations_volume.head(15).MV_21_01)
plt.show()
# Out:
# findfont: Font family ['CALIBRI'] not found. Falling back to DejaVu Sans.

# %%
# repeats this for all other months

# %%
df_21_02_stations_volume = df_21_02.groupby(['STATION'])['DAILY_VOLUME'].sum().sort_values(ascending = False)
df_21_02_stations_volume = pd.DataFrame(df_21_02_stations_volume.reset_index())
df_21_02_stations_volume = df_21_02_stations_volume.rename(columns={"DAILY_VOLUME":"MV_21_02"})
# df_21_02_stations_volume
# MV == Monthly Volume

# %%
df_21_03_stations_volume = df_21_03.groupby(['STATION'])['DAILY_VOLUME'].sum().sort_values(ascending = False)
df_21_03_stations_volume = pd.DataFrame(df_21_03_stations_volume.reset_index())
df_21_03_stations_volume = df_21_03_stations_volume.rename(columns={"DAILY_VOLUME":"MV_21_03"})

# %%
df_21_04_stations_volume = df_21_04.groupby(['STATION'])['DAILY_VOLUME'].sum().sort_values(ascending = False)
df_21_04_stations_volume = pd.DataFrame(df_21_04_stations_volume.reset_index())
df_21_04_stations_volume = df_21_04_stations_volume.rename(columns={"DAILY_VOLUME":"MV_21_04"})

# %%
df_21_05_stations_volume = df_21_05.groupby(['STATION'])['DAILY_VOLUME'].sum().sort_values(ascending = False)
df_21_05_stations_volume = pd.DataFrame(df_21_05_stations_volume.reset_index())
df_21_05_stations_volume = df_21_05_stations_volume.rename(columns={"DAILY_VOLUME":"MV_21_05"})

# %%
df_21_06_stations_volume = df_21_06.groupby(['STATION'])['DAILY_VOLUME'].sum().sort_values(ascending = False)
df_21_06_stations_volume = pd.DataFrame(df_21_06_stations_volume.reset_index())
df_21_06_stations_volume = df_21_06_stations_volume.rename(columns={"DAILY_VOLUME":"MV_21_06"})

# %%
df_21_07_stations_volume = df_21_07.groupby(['STATION'])['DAILY_VOLUME'].sum().sort_values(ascending = False)
df_21_07_stations_volume = pd.DataFrame(df_21_07_stations_volume.reset_index())
df_21_07_stations_volume = df_21_07_stations_volume.rename(columns={"DAILY_VOLUME":"MV_21_07"})

# %%
df_21_08_stations_volume = df_21_08.groupby(['STATION'])['DAILY_VOLUME'].sum().sort_values(ascending = False)
df_21_08_stations_volume = pd.DataFrame(df_21_08_stations_volume.reset_index())
df_21_08_stations_volume = df_21_08_stations_volume.rename(columns={"DAILY_VOLUME":"MV_21_08"})

# %%
df_21_09_stations_volume = df_21_09.groupby(['STATION'])['DAILY_VOLUME'].sum().sort_values(ascending = False)
df_21_09_stations_volume = pd.DataFrame(df_21_09_stations_volume.reset_index())
df_21_09_stations_volume = df_21_09_stations_volume.rename(columns={"DAILY_VOLUME":"MV_21_09"})

# %%
df_21_10_stations_volume = df_21_10.groupby(['STATION'])['DAILY_VOLUME'].sum().sort_values(ascending = False)
df_21_10_stations_volume = pd.DataFrame(df_21_10_stations_volume.reset_index())
df_21_10_stations_volume = df_21_10_stations_volume.rename(columns={"DAILY_VOLUME":"MV_21_10"})

# %%
df_21_11_stations_volume = df_21_11.groupby(['STATION'])['DAILY_VOLUME'].sum().sort_values(ascending = False)
df_21_11_stations_volume = pd.DataFrame(df_21_11_stations_volume.reset_index())
df_21_11_stations_volume = df_21_11_stations_volume.rename(columns={"DAILY_VOLUME":"MV_21_11"})

# %%
df_21_12_stations_volume = df_21_12.groupby(['STATION'])['DAILY_VOLUME'].sum().sort_values(ascending = False)
df_21_12_stations_volume = pd.DataFrame(df_21_12_stations_volume.reset_index())
df_21_12_stations_volume = df_21_12_stations_volume.rename(columns={"DAILY_VOLUME":"MV_21_12"})

# %%
import functools as ft
dfs = [df_21_01_stations_volume, df_21_02_stations_volume, df_21_03_stations_volume,df_21_04_stations_volume, df_21_05_stations_volume, df_21_06_stations_volume,df_21_07_stations_volume, df_21_08_stations_volume, df_21_09_stations_volume,df_21_10_stations_volume, df_21_11_stations_volume, df_21_12_stations_volume,]
df_21_stations_volume_all_year = ft.reduce(lambda left, right: pd.merge(left, right, on='STATION'), dfs)

# %%
df_21_stations_volume_all_year['YEAR_VOLUME'] = df_21_stations_volume_all_year.sum(axis=1, numeric_only=True)

# %%
df_21_stations_volume_all_year
# Out:
#              STATION   MV_21_01   MV_21_02   MV_21_03   MV_21_04   MV_21_05  \
# 0     34 ST-PENN STA  1469903.0  1415968.0  1649706.0  1745467.0  2000839.0
# 1             125 ST  1030262.0  1012840.0  1135913.0  1189007.0  1299177.0
# 2              23 ST   987764.0   971975.0  1141948.0  1210563.0  1393682.0
# 3              86 ST   975650.0   966866.0  1104181.0  1181810.0  1335826.0
# 4    34 ST-HERALD SQ   944578.0   912842.0  1046219.0  1106740.0  1254298.0
# ..               ...        ...        ...        ...        ...        ...
# 373      BEACH 90 ST    14011.0    17845.0    33293.0    14755.0    13441.0
# 374      BEACH 98 ST     7263.0     7343.0     8210.0     8713.0     7185.0
# 375    TOMPKINSVILLE     6790.0     6246.0     6869.0     7239.0     7692.0
# 376     BEACH 105 ST     3952.0     4218.0     4266.0     4691.0     4925.0
# 377    BROAD CHANNEL     3599.0     3559.0     4057.0     4171.0     4922.0
#
# ...

# %%
# make a copy of this
df_21_stations_volume_all_year_copy = df_21_stations_volume_all_year.copy(deep=True)

# df_21_stations_volume_all_year = df_21_stations_volume_all_year_copy

# %%
df_21_stations_volume_all_year = df_21_stations_volume_all_year.sort_values('YEAR_VOLUME',ascending=False)
df_21_stations_volume_all_year.head(15)
# Out:
#             STATION   MV_21_01   MV_21_02   MV_21_03   MV_21_04   MV_21_05  \
# 0    34 ST-PENN STA  1469903.0  1415968.0  1649706.0  1745467.0  2000839.0
# 2             23 ST   987764.0   971975.0  1141948.0  1210563.0  1393682.0
# 3             86 ST   975650.0   966866.0  1104181.0  1181810.0  1335826.0
# 5         FULTON ST   891874.0   864640.0  1016054.0  1078270.0  1238596.0
# 1            125 ST  1030262.0  1012840.0  1135913.0  1189007.0  1299177.0
# 7   GRD CNTRL-42 ST   814184.0   829427.0  1001423.0  1079864.0  1220828.0
# 4   34 ST-HERALD SQ   944578.0   912842.0  1046219.0  1106740.0  1254298.0
# 8    TIMES SQ-42 ST   789770.0   741985.0   901589.0   996335.0  1146675.0
# 6             59 ST   868756.0   877038.0   969019.0  1037572.0  1128403.0
# 9   42 ST-PORT AUTH   769649.0   746619.0   850776.0   907844.0  1014562.0
# 10   14 ST-UNION SQ   750766.0   738816.0   865016.0   926001.0  1046034.0
# ...

# %%
#Plot graph for TOP 15 STATIONS BASED ON YEARLY RIDERSHIP
plt.figure(figsize=(20,8))
plt.title('TOP 15 STATIONS BASED ON YEARLY VOLUME OF USERS of 2021',family='CALIBRI',fontsize = 20,loc='CENTER',color='black');
sns.barplot(data = df_21_stations_volume_all_year.head(15), y = df_21_stations_volume_all_year.head(15).STATION, x = df_21_stations_volume_all_year.head(15).YEAR_VOLUME)
plt.show()

# %%
# reperat for 2019
df_19_01_stations_volume = df_19_01.groupby(['STATION'])['DAILY_VOLUME'].sum().sort_values(ascending = False)
df_19_01_stations_volume = pd.DataFrame(df_19_01_stations_volume.reset_index())
df_19_01_stations_volume = df_19_01_stations_volume.rename(columns={"DAILY_VOLUME":"MV_19_01"})

# %%
df_19_02_stations_volume = df_19_02.groupby(['STATION'])['DAILY_VOLUME'].sum().sort_values(ascending = False)
df_19_02_stations_volume = pd.DataFrame(df_19_02_stations_volume.reset_index())
df_19_02_stations_volume = df_19_02_stations_volume.rename(columns={"DAILY_VOLUME":"MV_19_02"})

# %%
df_19_03_stations_volume = df_19_03.groupby(['STATION'])['DAILY_VOLUME'].sum().sort_values(ascending = False)
df_19_03_stations_volume = pd.DataFrame(df_19_03_stations_volume.reset_index())
df_19_03_stations_volume = df_19_03_stations_volume.rename(columns={"DAILY_VOLUME":"MV_19_03"})

# %%
df_19_04_stations_volume = df_19_04.groupby(['STATION'])['DAILY_VOLUME'].sum().sort_values(ascending = False)
df_19_04_stations_volume = pd.DataFrame(df_19_04_stations_volume.reset_index())
df_19_04_stations_volume = df_19_04_stations_volume.rename(columns={"DAILY_VOLUME":"MV_19_04"})

# %%
df_19_05_stations_volume = df_19_05.groupby(['STATION'])['DAILY_VOLUME'].sum().sort_values(ascending = False)
df_19_05_stations_volume = pd.DataFrame(df_19_05_stations_volume.reset_index())
df_19_05_stations_volume = df_19_05_stations_volume.rename(columns={"DAILY_VOLUME":"MV_19_05"})

# %%
df_19_06_stations_volume = df_19_06.groupby(['STATION'])['DAILY_VOLUME'].sum().sort_values(ascending = False)
df_19_06_stations_volume = pd.DataFrame(df_19_06_stations_volume.reset_index())
df_19_06_stations_volume = df_19_06_stations_volume.rename(columns={"DAILY_VOLUME":"MV_19_06"})

# %%
df_19_07_stations_volume = df_19_07.groupby(['STATION'])['DAILY_VOLUME'].sum().sort_values(ascending = False)
df_19_07_stations_volume = pd.DataFrame(df_19_07_stations_volume.reset_index())
df_19_07_stations_volume = df_19_07_stations_volume.rename(columns={"DAILY_VOLUME":"MV_19_07"})

# %%
df_19_08_stations_volume = df_19_08.groupby(['STATION'])['DAILY_VOLUME'].sum().sort_values(ascending = False)
df_19_08_stations_volume = pd.DataFrame(df_19_08_stations_volume.reset_index())
df_19_08_stations_volume = df_19_08_stations_volume.rename(columns={"DAILY_VOLUME":"MV_19_08"})

# %%
df_19_09_stations_volume = df_19_09.groupby(['STATION'])['DAILY_VOLUME'].sum().sort_values(ascending = False)
df_19_09_stations_volume = pd.DataFrame(df_19_09_stations_volume.reset_index())
df_19_09_stations_volume = df_19_09_stations_volume.rename(columns={"DAILY_VOLUME":"MV_19_09"})

# %%
df_19_10_stations_volume = df_19_10.groupby(['STATION'])['DAILY_VOLUME'].sum().sort_values(ascending = False)
df_19_10_stations_volume = pd.DataFrame(df_19_10_stations_volume.reset_index())
df_19_10_stations_volume = df_19_10_stations_volume.rename(columns={"DAILY_VOLUME":"MV_19_10"})

# %%
df_19_11_stations_volume = df_19_11.groupby(['STATION'])['DAILY_VOLUME'].sum().sort_values(ascending = False)
df_19_11_stations_volume = pd.DataFrame(df_19_11_stations_volume.reset_index())
df_19_11_stations_volume = df_19_11_stations_volume.rename(columns={"DAILY_VOLUME":"MV_19_11"})

# %%
df_19_12_stations_volume = df_19_12.groupby(['STATION'])['DAILY_VOLUME'].sum().sort_values(ascending = False)
df_19_12_stations_volume = pd.DataFrame(df_19_12_stations_volume.reset_index())
df_19_12_stations_volume = df_19_12_stations_volume.rename(columns={"DAILY_VOLUME":"MV_19_12"})

# %%
dfs_19 = [df_19_01_stations_volume, df_19_02_stations_volume, df_19_03_stations_volume,df_19_04_stations_volume, df_19_05_stations_volume, df_19_06_stations_volume,df_19_07_stations_volume, df_19_08_stations_volume, df_19_09_stations_volume,df_19_10_stations_volume, df_19_11_stations_volume, df_19_12_stations_volume,]
df_19_stations_volume_all_year = ft.reduce(lambda left, right: pd.merge(left, right, on='STATION'), dfs_19)

# %%
df_19_stations_volume_all_year['YEAR_VOLUME'] = df_19_stations_volume_all_year.sum(axis=1, numeric_only=True)

# %%
df_19_stations_volume_all_year
# Out:
#              STATION   MV_19_01   MV_19_02   MV_19_03   MV_19_04   MV_19_05  \
# 0     34 ST-PENN STA  5504929.0  5868708.0  6418875.0  6534938.0  6657381.0
# 1              23 ST  3884682.0  4363936.0  4384837.0  4374476.0  4368606.0
# 2    GRD CNTRL-42 ST  3823963.0  3986867.0  4487548.0  4482559.0  4225514.0
# 3    34 ST-HERALD SQ  3661640.0  3797892.0  4020062.0  4004639.0  4055333.0
# 4     TIMES SQ-42 ST  3444907.0  3651732.0  3819856.0  3995950.0  4004943.0
# ..               ...        ...        ...        ...        ...        ...
# 372      BEACH 98 ST    19361.0    18837.0    21741.0    21559.0    22436.0
# 373    TOMPKINSVILLE    16493.0    16045.0    18234.0    19015.0    20203.0
# 374     BEACH 105 ST     9898.0     9788.0    11511.0    11301.0    11660.0
# 375    BROAD CHANNEL     7737.0     8858.0     9272.0     9192.0     9369.0
# 376            39 AV       15.0    86202.0   105797.0   120448.0   145010.0
#
# ...

# %%
# make a copy of this
df_19_stations_volume_all_year_copy = df_19_stations_volume_all_year.copy(deep=True)

# df_19_stations_volume_all_year = df_21_stations_volume_all_year_copy

# %%
df_19_stations_volume_all_year = df_19_stations_volume_all_year.sort_values('YEAR_VOLUME',ascending=False)
df_19_stations_volume_all_year.head(15)
# Out:
#             STATION   MV_19_01   MV_19_02   MV_19_03   MV_19_04   MV_19_05  \
# 0    34 ST-PENN STA  5504929.0  5868708.0  6418875.0  6534938.0  6657381.0
# 1             23 ST  3884682.0  4363936.0  4384837.0  4374476.0  4368606.0
# 2   GRD CNTRL-42 ST  3823963.0  3986867.0  4487548.0  4482559.0  4225514.0
# 3   34 ST-HERALD SQ  3661640.0  3797892.0  4020062.0  4004639.0  4055333.0
# 4    TIMES SQ-42 ST  3444907.0  3651732.0  3819856.0  3995950.0  4004943.0
# 5         FULTON ST  3243194.0  3504207.0  3842238.0  3947543.0  4065620.0
# 6   42 ST-PORT AUTH  3147133.0  3335721.0  3523662.0  3613560.0  3698812.0
# 9            125 ST  2966979.0  3280439.0  3479358.0  3439859.0  3595036.0
# 7             86 ST  3136348.0  3263934.0  3455643.0  3528528.0  3597092.0
# 8    14 ST-UNION SQ  2999947.0  3181593.0  3216745.0  3292789.0  3546112.0
# 10         CANAL ST  2547402.0  2717001.0  2907803.0  3065215.0  3093896.0
# ...

# %%
#Plot graph for TOP 15 STATIONS BASED ON YEARLY RIDERSHIP
plt.figure(figsize=(20,8))
plt.title('TOP 15 STATIONS BASED ON YEARLY VOLUME OF USERS of 2019',family='CALIBRI',fontsize = 20,loc='CENTER',color='black');
sns.barplot(data = df_19_stations_volume_all_year.head(15), y = df_19_stations_volume_all_year.head(15).STATION, x = df_19_stations_volume_all_year.head(15).YEAR_VOLUME)
plt.show()

# %%
df_all_stations_19_and_21 = df_19_stations_volume_all_year.merge(df_21_stations_volume_all_year, on='STATION')
# left.merge(right, on='key')

# %%
df_all_stations_19_and_21 = df_all_stations_19_and_21.rename(columns={'YEAR_VOLUME_x':'19_VOLUME','YEAR_VOLUME_y':'21_VOLUME'})
df_all_stations_19_and_21
# Out:
#              STATION   MV_19_01   MV_19_02   MV_19_03   MV_19_04   MV_19_05  \
# 0     34 ST-PENN STA  5504929.0  5868708.0  6418875.0  6534938.0  6657381.0
# 1              23 ST  3884682.0  4363936.0  4384837.0  4374476.0  4368606.0
# 2    GRD CNTRL-42 ST  3823963.0  3986867.0  4487548.0  4482559.0  4225514.0
# 3    34 ST-HERALD SQ  3661640.0  3797892.0  4020062.0  4004639.0  4055333.0
# 4     TIMES SQ-42 ST  3444907.0  3651732.0  3819856.0  3995950.0  4004943.0
# ..               ...        ...        ...        ...        ...        ...
# 372      BEACH 44 ST    33786.0    36493.0    39859.0    38335.0    36030.0
# 373      BEACH 98 ST    19361.0    18837.0    21741.0    21559.0    22436.0
# 374    TOMPKINSVILLE    16493.0    16045.0    18234.0    19015.0    20203.0
# 375     BEACH 105 ST     9898.0     9788.0    11511.0    11301.0    11660.0
# 376    BROAD CHANNEL     7737.0     8858.0     9272.0     9192.0     9369.0
#
# ...

# %%
# make a copy of this
df_all_stations_19_and_21_copy = df_all_stations_19_and_21.copy(deep=True)
# df_all_stations_19_and_21 = df_all_stations_19_and_21_copy

# %%
df_all_stations_19_and_21['Yearly_change'] = df_all_stations_19_and_21['21_VOLUME']-df_all_stations_19_and_21['19_VOLUME']
df_all_stations_19_and_21['Yearly_percentage_change'] = 100*(df_all_stations_19_and_21['21_VOLUME']-df_all_stations_19_and_21['19_VOLUME'])/df_all_stations_19_and_21['19_VOLUME']

# %%
df_all_stations_19_and_21
# Out:
#              STATION   MV_19_01   MV_19_02   MV_19_03   MV_19_04   MV_19_05  \
# 0     34 ST-PENN STA  5504929.0  5868708.0  6418875.0  6534938.0  6657381.0
# 1              23 ST  3884682.0  4363936.0  4384837.0  4374476.0  4368606.0
# 2    GRD CNTRL-42 ST  3823963.0  3986867.0  4487548.0  4482559.0  4225514.0
# 3    34 ST-HERALD SQ  3661640.0  3797892.0  4020062.0  4004639.0  4055333.0
# 4     TIMES SQ-42 ST  3444907.0  3651732.0  3819856.0  3995950.0  4004943.0
# ..               ...        ...        ...        ...        ...        ...
# 372      BEACH 44 ST    33786.0    36493.0    39859.0    38335.0    36030.0
# 373      BEACH 98 ST    19361.0    18837.0    21741.0    21559.0    22436.0
# 374    TOMPKINSVILLE    16493.0    16045.0    18234.0    19015.0    20203.0
# 375     BEACH 105 ST     9898.0     9788.0    11511.0    11301.0    11660.0
# 376    BROAD CHANNEL     7737.0     8858.0     9272.0     9192.0     9369.0
#
# ...

# %%
# make a copy of this
df_all_stations_19_and_21_copy_2 = df_all_stations_19_and_21.copy(deep=True)
# df_all_stations_19_and_21 = df_all_stations_19_and_21_copy_2

# %%
df_all_stations_19_and_21.sort_values('Yearly_percentage_change',ascending=False)
df_all_stations_19_and_21.head(15)
# Out:
#             STATION   MV_19_01   MV_19_02   MV_19_03   MV_19_04   MV_19_05  \
# 0    34 ST-PENN STA  5504929.0  5868708.0  6418875.0  6534938.0  6657381.0
# 1             23 ST  3884682.0  4363936.0  4384837.0  4374476.0  4368606.0
# 2   GRD CNTRL-42 ST  3823963.0  3986867.0  4487548.0  4482559.0  4225514.0
# 3   34 ST-HERALD SQ  3661640.0  3797892.0  4020062.0  4004639.0  4055333.0
# 4    TIMES SQ-42 ST  3444907.0  3651732.0  3819856.0  3995950.0  4004943.0
# 5         FULTON ST  3243194.0  3504207.0  3842238.0  3947543.0  4065620.0
# 6   42 ST-PORT AUTH  3147133.0  3335721.0  3523662.0  3613560.0  3698812.0
# 7            125 ST  2966979.0  3280439.0  3479358.0  3439859.0  3595036.0
# 8             86 ST  3136348.0  3263934.0  3455643.0  3528528.0  3597092.0
# 9    14 ST-UNION SQ  2999947.0  3181593.0  3216745.0  3292789.0  3546112.0
# 10         CANAL ST  2547402.0  2717001.0  2907803.0  3065215.0  3093896.0
# ...

# %%
df_all_stations_19_and_21.to_csv (r'/home/kenan/Desktop/Metis_DS_BC_2022/MetisBC/Exploratory Data Analysis/Project_Turnstile_data/df_all_stations_19_and_21.csv', index = None, header=True)

# %%
from matplotlib.pyplot import figure

monthly_19_penn_sta = df_all_stations_19_and_21.iloc[0,1:13]
monthly_21_penn_sta = df_all_stations_19_and_21.iloc[0,14:26]

plotdata = pd.DataFrame({
    "monthly_volumes_2019": list(monthly_19_penn_sta),
    "monthly_volumes_2020": list(monthly_21_penn_sta),
    }, 
    index=["Jan", "Feb", "Mar", "Apr", 'May', "June", "July", "Aug", "Sep", "Oct", "Nov", "Dec"]
)

plotdata.plot(kind="bar")

plt.title("Penn Station Pre and Post Covid Values")
plt.xlabel("Months")
plt.ylabel("Monthly Volume")
# Put a legend to the right of the current axis
plt.legend(bbox_to_anchor=(1.04,1), borderaxespad=0)

# %%
# monthly_19_penn_sta , monthly_21_penn_sta

# %%
top_15_2019_list = df_all_stations_19_and_21.sort_values('19_VOLUME',ascending=False).head(15)
top_15_2019_list = top_15_2019_list[['STATION','19_VOLUME']]
top_15_2019_list
# Out:
#             STATION   19_VOLUME
# 0    34 ST-PENN STA  75460903.0
# 1             23 ST  51235577.0
# 2   GRD CNTRL-42 ST  48701552.0
# 3   34 ST-HERALD SQ  46924605.0
# 4    TIMES SQ-42 ST  46079696.0
# 5         FULTON ST  45831902.0
# 6   42 ST-PORT AUTH  42317002.0
# 7            125 ST  40727497.0
# 8             86 ST  40578975.0
# 9    14 ST-UNION SQ  39820475.0
# 10         CANAL ST  35069278.0
# 11            14 ST  31472644.0
# 12            59 ST  30975672.0
# 13   59 ST COLUMBUS  30421572.0
# 14            96 ST  29521151.0

# %%
top_15_2021_list = df_all_stations_19_and_21.sort_values('21_VOLUME',ascending=False).head(15)
top_15_2021_list = top_15_2021_list[['STATION','21_VOLUME']].reset_index()
top_15_2021_list
# Out:
#     index          STATION   21_VOLUME
# 0       0   34 ST-PENN STA  26442603.0
# 1       1            23 ST  18075949.0
# 2       8            86 ST  16368507.0
# 3       5        FULTON ST  16237538.0
# 4       7           125 ST  16191877.0
# 5       2  GRD CNTRL-42 ST  16098202.0
# 6       3  34 ST-HERALD SQ  15972149.0
# 7       4   TIMES SQ-42 ST  14911607.0
# 8      12            59 ST  14108627.0
# 9       6  42 ST-PORT AUTH  13816841.0
# 10      9   14 ST-UNION SQ  13007608.0
# 11     10         CANAL ST  12453778.0
# 12     14            96 ST  12099413.0
# 13     11            14 ST  11924048.0
# 14     13   59 ST COLUMBUS  10867582.0

# %%
# top_15_2019_list['STATION']

# %%
import matplotlib.pyplot as plt

labels1 = top_15_2019_list['STATION']
fracs1 = top_15_2019_list['19_VOLUME']
labels2 = top_15_2021_list['STATION']
fracs2 = top_15_2021_list['21_VOLUME']

fig = plt.figure()

ax1 = fig.add_axes([-.5, -0.5, .4, .4], aspect=2)
ax1.pie(fracs1, labels=labels1, radius = 3)
ax2 = fig.add_axes([0.5, 0.5, .4, .4], aspect=2)
ax2.pie(fracs2, labels=labels2, radius = 3)
ax1.set_title('2019')
ax2.set_title('2021')
plt.show()
